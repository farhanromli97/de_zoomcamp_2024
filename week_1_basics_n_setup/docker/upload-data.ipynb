# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv.gz', nrows=100)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv.gz', iterator=True,chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52                3
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45                2
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22                2
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37                2
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44                5
#
# ...

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 2.94 s, sys: 59.2 ms, total: 3 s
# Wall time: 5.26 s
# 1000

# %%
from time import time

while True: 
    try:
        t_start = time()
        df = next(df_iter)

        df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
        df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
        
        df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

        t_end = time()

        print('inserted another chunk, took %.3f second' % (t_end - t_start))
    except StopIteration:
        print('completed')
        break
# Out:
# inserted another chunk, took 5.320 second
# inserted another chunk, took 5.163 second
# inserted another chunk, took 5.190 second
# inserted another chunk, took 5.262 second
# inserted another chunk, took 5.156 second
# inserted another chunk, took 5.127 second
# inserted another chunk, took 5.538 second
# inserted another chunk, took 5.465 second
# inserted another chunk, took 5.265 second
# inserted another chunk, took 5.273 second
# inserted another chunk, took 5.534 second
# /var/folders/59/3jkqknx52436z0m2xvwc17rm0000gn/T/ipykernel_5665/74935928.py:6: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk, took 5.347 second
# inserted another chunk, took 3.645 second
# completed

# %%
df_zone = pd.read_csv('taxi_zone_lookup.csv')

# %%
df_zone.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zone.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265

# %%
df2 = pd.read_csv('green_tripdata_2019-09.csv.gz', nrows=100)

# %%
df2.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1         2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2         2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3         2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4         2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            65           189                5           2.00
# 1           1            97           225                5           3.20
# 2           1            37            61                5           2.99
# 3           1           145           112                1           1.73
# 4           1           112           198                1           3.42
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df_green_iter = pd.read_csv('green_tripdata_2019-09.csv.gz', iterator=True,chunksize=100000)

# %%
df_green = next(df_green_iter)

# %%
df_green.lpep_pickup_datetime = pd.to_datetime(df_green.lpep_pickup_datetime)
df_green.lpep_dropoff_datetime = pd.to_datetime(df_green.lpep_dropoff_datetime)
df_green
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1             2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2             2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3             2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4             2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-09-08 21:34:31   2019-09-08 21:42:44                  N
# 99996         2  2019-09-08 21:06:54   2019-09-08 21:12:38                  N
# 99997         2  2019-09-08 21:22:10   2019-09-08 21:29:33                  N
# 99998         2  2019-09-08 21:33:42   2019-09-08 21:33:48                  N
# 99999         2  2019-09-08 21:29:16   2019-09-08 21:36:45                  N
#
# ...

# %%
df_green.head(n=0).to_sql(name='green_taxi_trips', con=engine, if_exists='replace')
# Out:
# 0

# %%
df_green.to_sql(name='green_taxi_trips', con=engine, if_exists='append')
# Out:
# 1000

# %%
from time import time

while True: 
    try:
        t_start = time()
        df_green = next(df_green_iter)

        df_green.lpep_pickup_datetime = pd.to_datetime(df_green.lpep_pickup_datetime)
        df_green.lpep_dropoff_datetime = pd.to_datetime(df_green.lpep_dropoff_datetime)
        
        df_green.to_sql(name='green_taxi_trips', con=engine, if_exists='append')

        t_end = time()

        print('inserted another chunk, took %.3f second' % (t_end - t_start))
    except StopIteration:
        print('completed')
        break
# Out:
# inserted another chunk, took 5.391 second
# inserted another chunk, took 5.210 second
# /var/folders/59/3jkqknx52436z0m2xvwc17rm0000gn/T/ipykernel_5665/192793427.py:6: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_green = next(df_green_iter)
# inserted another chunk, took 5.154 second
# inserted another chunk, took 2.387 second
# completed
